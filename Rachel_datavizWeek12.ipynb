# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = 'newActivity.csv'
df = pd.read_csv(filename)

# %%
#adding new factor variables in the dataset, weekday and weekend
df['date'] = pd.to_datetime(df['date']) #converting the date column in the csv file to date time
df['dayOfweek'] = df['date'].dt.dayofweek #determining which day of the week it is
df['isWeekday'] = df['date'].dt.dayofweek < 5 #column for weekdays
df['isWeekend'] = df['date'].dt.dayofweek > 5 #column for weekends
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25508/3025843666.py in <module>
#       1 #adding new factor variables in the dataset, weekday and weekend
# ----> 2 df['date'] = pd.to_datetime(df['date']) #converting the date column in the csv file to date time
#       3 df['dayOfweek'] = df['date'].dt.dayofweek #determining which day of the week it is
#       4 df['isWeekday'] = df['date'].dt.dayofweek < 5 #column for weekdays
#       5 df['isWeekend'] = df['date'].dt.dayofweek > 5 #column for weekends
#
# NameError: name 'pd' is not defined

# %%
#finding the average steps for the weekday
#separating it into a different dataframe
avgWkdy= pd.DataFrame(df['isWeekday'])
avgWkdy['interval'] = df['interval']
avgWkdy['steps'] = df['steps']

# %%
#finding the average steps for the weekend
#separating it into a different dataframe
avgWked = pd.DataFrame(df['isWeekend'])
avgWked['interval'] = df['interval']
avgWked['steps'] = df['steps']

# %%
#using the aggregate function to sort the average from each interval to either a weekday or a weekend
#weekday average
avgWkdy = avgWkdy.groupby(['interval', 'isWeekday']).agg({'steps':'mean'})

#weekend average
avgWked = avgWked.groupby(['interval', 'isWeekend']).agg({'steps':'mean'})

# %%
avgWkdy = avgWkdy.reset_index()
avgWkdy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25508/2084428060.py in <module>
# ----> 1 avgWkdy = avgWkdy.reset_index()
#       2 avgWkdy
#
# NameError: name 'avgWkdy' is not defined

# %%
avgWked = avgWked.reset_index()
avgWked
# Out:
#      interval  isWeekend     steps
# 0           0      False  1.750000
# 1           0       True  0.000000
# 2           5      False  0.339623
# 3           5       True  0.000000
# 4          10      False  0.132075
# ..        ...        ...       ...
# 571      2345       True  3.250000
# 572      2350      False  0.226415
# 573      2350       True  0.000000
# 574      2355      False  1.075472
# 575      2355       True  0.000000
#
# [576 rows x 3 columns]

# %%
#plotting the two graphs
#graph 1 (weekdays)
avgWkdy.plot('interval', 'steps', xlabel='Time Interval', ylabel='Average Number of Steps Taken', title='Weekdays', figsize=(20,6))
avgWked.plot('interval', 'steps',xlabel='Time Interval', ylabel='Average Number of Steps Taken', title='Weekends', color='purple', figsize=(20,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25508/3137884901.py in <module>
#       1 #plotting the two graphs
#       2 #graph 1 (weekdays)
# ----> 3 avgWkdy.plot('interval', 'steps', xlabel='Time Interval', ylabel='Average Number of Steps Taken', title='Weekdays', figsize=(20,6))
#       4 avgWked.plot('interval', 'steps',xlabel='Time Interval', ylabel='Average Number of Steps Taken', title='Weekends', color='purple', figsize=(20,6))
#
# NameError: name 'avgWkdy' is not defined
